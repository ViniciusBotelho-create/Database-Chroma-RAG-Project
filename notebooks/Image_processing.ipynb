# %%
import fitz 
from pathlib import Path
from PIL import Image
import pytesseract
import os
import shutil
from PIL import Image, ImageEnhance, ImageFilter
import os
import re
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.utils import embedding_functions
from pymongo import MongoClient
import uuid

# %%
# Caminho dos PDFs
pdf_folder_path = Path("../pdf_documents")
pdf_files = [f for f in os.listdir(pdf_folder_path) if f.endswith(".pdf")]

# Caminho de saída para as imagens
output_dir = Path("../extracted_images")
output_dir.mkdir(parents=True, exist_ok=True)

print(f"Extraindo imagens para: {output_dir.resolve()}\n")

# Função para extrair imagens embutidas de um PDF
def extract_images_from_pdf(pdf_path: Path):
    pdf_name = pdf_path.stem
    with fitz.open(pdf_path) as doc:
        for page_number in range(len(doc)):
            page = doc[page_number]
            images = page.get_images(full=True)
            
            for img_index, img in enumerate(images):
                xref = img[0]
                try:
                    base_image = doc.extract_image(xref)
                    image_bytes = base_image["image"]
                    image_ext = base_image["ext"]

                    # Nome do arquivo: nomeDoArquivo_paginaX_imgY.ext
                    image_filename = f"{pdf_name}_pagina{page_number+1}_img{img_index+1}.{image_ext}"
                    image_path = output_dir / image_filename

                    with open(image_path, "wb") as f:
                        f.write(image_bytes)
                    
                    print(f"Imagem salva: {image_filename}")
                except Exception as e:
                    print(f"Erro ao extrair imagem {img_index+1} da página {page_number+1} em {pdf_name}: {e}")

# Processar todos os PDFs
for pdf_file in pdf_files:
    pdf_path = pdf_folder_path / pdf_file
    print(f"\nProcessando: {pdf_file}")
    extract_images_from_pdf(pdf_path)

print("\nExtração de imagens concluída.")
# Out:
# Extraindo imagens para: /home/stoiccode/gitRepositories/Database-Chroma-RAG-Project/extracted_images
#
#
# 📄 Processando: RIMA_example1.pdf
# Imagem salva: RIMA_example1_pagina1_img1.jpeg
# Imagem salva: RIMA_example1_pagina2_img1.jpeg
# Imagem salva: RIMA_example1_pagina3_img1.jpeg
# Imagem salva: RIMA_example1_pagina3_img2.jpeg
# Imagem salva: RIMA_example1_pagina3_img3.jpeg
# Imagem salva: RIMA_example1_pagina3_img4.jpeg
# Imagem salva: RIMA_example1_pagina3_img5.jpeg
# Imagem salva: RIMA_example1_pagina4_img1.jpeg
# Imagem salva: RIMA_example1_pagina5_img1.jpeg
# Imagem salva: RIMA_example1_pagina5_img2.jpeg
# Imagem salva: RIMA_example1_pagina8_img1.jpeg
# Imagem salva: RIMA_example1_pagina8_img2.jpeg
# Imagem salva: RIMA_example1_pagina9_img1.jpeg
# Imagem salva: RIMA_example1_pagina9_img2.jpeg
# Imagem salva: RIMA_example1_pagina10_img1.jpeg
# Imagem salva: RIMA_example1_pagina10_img2.jpeg
# Imagem salva: RIMA_example1_pagina10_img3.jpeg
# Imagem salva: RIMA_example1_pagina11_img1.jpeg
# Imagem salva: RIMA_example1_pagina13_img1.jpeg
# Imagem salva: RIMA_example1_pagina13_img2.jpeg
# Imagem salva: RIMA_example1_pagina13_img3.jpeg
# Imagem salva: RIMA_example1_pagina13_img4.jpeg
# Imagem salva: RIMA_example1_pagina13_img5.jpeg
# Imagem salva: RIMA_example1_pagina13_img6.jpeg
# Imagem salva: RIMA_example1_pagina13_img7.jpeg
# Imagem salva: RIMA_example1_pagina13_img8.jpeg
# Imagem salva: RIMA_example1_pagina13_img9.jpeg
# Imagem salva: RIMA_example1_pagina14_img1.jpeg
# Imagem salva: RIMA_example1_pagina14_img2.jpeg
# Imagem salva: RIMA_example1_pagina14_img3.jpeg
# Imagem salva: RIMA_example1_pagina15_img1.jpeg
# Imagem salva: RIMA_example1_pagina15_img2.jpeg
# Imagem salva: RIMA_example1_pagina15_img3.jpeg
# Imagem salva: RIMA_example1_pagina15_img4.jpeg
# Imagem salva: RIMA_example1_pagina16_img1.jpeg
# Imagem salva: RIMA_example1_pagina17_img1.jpeg
# Imagem salva: RIMA_example1_pagina17_img2.jpeg
# Imagem salva: RIMA_example1_pagina17_img3.jpeg
# Imagem salva: RIMA_example1_pagina18_img1.jpeg
# Imagem salva: RIMA_example1_pagina18_img2.jpeg
# Imagem salva: RIMA_example1_pagina18_img3.jpeg
# Imagem salva: RIMA_example1_pagina18_img4.jpeg
# Imagem salva: RIMA_example1_pagina19_img1.jpeg
# Imagem salva: RIMA_example1_pagina20_img1.jpeg
# Imagem salva: RIMA_example1_pagina20_img2.jpeg
# Imagem salva: RIMA_example1_pagina21_img1.jpeg
# Imagem salva: RIMA_example1_pagina21_img2.jpeg
# Imagem salva: RIMA_example1_pagina21_img3.jpeg
# Imagem salva: RIMA_example1_pagina21_img4.jpeg
# Imagem salva: RIMA_example1_pagina22_img1.jpeg
# Imagem salva: RIMA_example1_pagina22_img2.jpeg
# Imagem salva: RIMA_example1_pagina23_img1.jpeg
# Imagem salva: RIMA_example1_pagina23_img2.jpeg
# Imagem salva: RIMA_example1_pagina24_img1.jpeg
# Imagem salva: RIMA_example1_pagina25_img1.jpeg
# Imagem salva: RIMA_example1_pagina25_img2.jpeg
# Imagem salva: RIMA_example1_pagina25_img3.jpeg
# Imagem salva: RIMA_example1_pagina25_img4.jpeg
# Imagem salva: RIMA_example1_pagina25_img5.png
# Imagem salva: RIMA_example1_pagina26_img1.jpeg
# Imagem salva: RIMA_example1_pagina26_img2.jpeg
# Imagem salva: RIMA_example1_pagina26_img3.jpeg
# Imagem salva: RIMA_example1_pagina26_img4.jpeg
# Imagem salva: RIMA_example1_pagina26_img5.jpeg
# Imagem salva: RIMA_example1_pagina27_img1.jpeg
# Imagem salva: RIMA_example1_pagina28_img1.jpeg
# Imagem salva: RIMA_example1_pagina28_img2.jpeg
# Imagem salva: RIMA_example1_pagina28_img3.jpeg
# Imagem salva: RIMA_example1_pagina28_img4.jpeg
# Imagem salva: RIMA_example1_pagina29_img1.jpeg
# Imagem salva: RIMA_example1_pagina29_img2.jpeg
# Imagem salva: RIMA_example1_pagina29_img3.jpeg
# Imagem salva: RIMA_example1_pagina29_img4.jpeg
# Imagem salva: RIMA_example1_pagina29_img5.jpeg
# Imagem salva: RIMA_example1_pagina29_img6.jpeg
# Imagem salva: RIMA_example1_pagina29_img7.jpeg
# Imagem salva: RIMA_example1_pagina30_img1.jpeg
# Imagem salva: RIMA_example1_pagina30_img2.jpeg
# Imagem salva: RIMA_example1_pagina30_img3.jpeg
# Imagem salva: RIMA_example1_pagina30_img4.jpeg
# Imagem salva: RIMA_example1_pagina30_img5.jpeg
# Imagem salva: RIMA_example1_pagina31_img1.jpeg
# Imagem salva: RIMA_example1_pagina31_img2.jpeg
# Imagem salva: RIMA_example1_pagina31_img3.jpeg
# Imagem salva: RIMA_example1_pagina32_img1.jpeg
# Imagem salva: RIMA_example1_pagina33_img1.jpeg
# Imagem salva: RIMA_example1_pagina33_img2.jpeg
#
# 📄 Processando: EIA_example1.pdf
# Imagem salva: EIA_example1_pagina1_img1.png
# Imagem salva: EIA_example1_pagina1_img2.png
# Imagem salva: EIA_example1_pagina2_img1.png
# Imagem salva: EIA_example1_pagina2_img2.png
# Imagem salva: EIA_example1_pagina3_img1.png
# Imagem salva: EIA_example1_pagina3_img2.png
# Imagem salva: EIA_example1_pagina4_img1.png
# Imagem salva: EIA_example1_pagina4_img2.png
# Imagem salva: EIA_example1_pagina5_img1.png
# Imagem salva: EIA_example1_pagina5_img2.png
# Imagem salva: EIA_example1_pagina6_img1.png
# Imagem salva: EIA_example1_pagina6_img2.png
# Imagem salva: EIA_example1_pagina7_img1.png
# Imagem salva: EIA_example1_pagina7_img2.png
# Imagem salva: EIA_example1_pagina8_img1.png
# Imagem salva: EIA_example1_pagina8_img2.png
# Imagem salva: EIA_example1_pagina9_img1.png
# Imagem salva: EIA_example1_pagina9_img2.png
# Imagem salva: EIA_example1_pagina10_img1.png
# Imagem salva: EIA_example1_pagina10_img2.png
# Imagem salva: EIA_example1_pagina11_img1.png
# Imagem salva: EIA_example1_pagina11_img2.png
# Imagem salva: EIA_example1_pagina12_img1.png
# Imagem salva: EIA_example1_pagina12_img2.png
# Imagem salva: EIA_example1_pagina13_img1.png
# Imagem salva: EIA_example1_pagina13_img2.png
# Imagem salva: EIA_example1_pagina14_img1.png
# Imagem salva: EIA_example1_pagina14_img2.png
# Imagem salva: EIA_example1_pagina15_img1.png
# Imagem salva: EIA_example1_pagina15_img2.png
# Imagem salva: EIA_example1_pagina16_img1.png
# Imagem salva: EIA_example1_pagina16_img2.png
# Imagem salva: EIA_example1_pagina17_img1.png
# Imagem salva: EIA_example1_pagina19_img1.png
# Imagem salva: EIA_example1_pagina19_img2.png
# Imagem salva: EIA_example1_pagina20_img1.png
# Imagem salva: EIA_example1_pagina20_img2.png
# Imagem salva: EIA_example1_pagina20_img3.png
# Imagem salva: EIA_example1_pagina23_img1.jpeg
# Imagem salva: EIA_example1_pagina24_img1.jpeg
# Imagem salva: EIA_example1_pagina24_img2.jpeg
# Imagem salva: EIA_example1_pagina24_img3.jpeg
# Imagem salva: EIA_example1_pagina25_img1.jpeg
# Imagem salva: EIA_example1_pagina26_img1.png
# Imagem salva: EIA_example1_pagina26_img2.jpeg
# Imagem salva: EIA_example1_pagina27_img1.jpeg
# Imagem salva: EIA_example1_pagina28_img1.jpeg
# Imagem salva: EIA_example1_pagina29_img1.jpeg
# Imagem salva: EIA_example1_pagina30_img1.jpeg
# Imagem salva: EIA_example1_pagina31_img1.jpeg
# Imagem salva: EIA_example1_pagina32_img1.jpeg
# Imagem salva: EIA_example1_pagina33_img1.jpeg
# Imagem salva: EIA_example1_pagina34_img1.jpeg
# Imagem salva: EIA_example1_pagina35_img1.jpeg
# Imagem salva: EIA_example1_pagina36_img1.jpeg
# Imagem salva: EIA_example1_pagina37_img1.jpeg
# Imagem salva: EIA_example1_pagina38_img1.jpeg
# Imagem salva: EIA_example1_pagina39_img1.png
# Imagem salva: EIA_example1_pagina39_img2.png
# Imagem salva: EIA_example1_pagina39_img3.png
# Imagem salva: EIA_example1_pagina39_img4.png
# Imagem salva: EIA_example1_pagina39_img5.jpeg
# Imagem salva: EIA_example1_pagina39_img6.png
# Imagem salva: EIA_example1_pagina39_img7.png
# Imagem salva: EIA_example1_pagina39_img8.jpeg
# Imagem salva: EIA_example1_pagina39_img9.jpeg
# Imagem salva: EIA_example1_pagina39_img10.jpeg
# Imagem salva: EIA_example1_pagina40_img1.png
# Imagem salva: EIA_example1_pagina40_img2.png
# Imagem salva: EIA_example1_pagina40_img3.png
# Imagem salva: EIA_example1_pagina40_img4.png
# Imagem salva: EIA_example1_pagina40_img5.jpeg
# Imagem salva: EIA_example1_pagina40_img6.png
# Imagem salva: EIA_example1_pagina40_img7.png
# Imagem salva: EIA_example1_pagina40_img8.jpeg
# Imagem salva: EIA_example1_pagina40_img9.jpeg
# Imagem salva: EIA_example1_pagina40_img10.jpeg
# Imagem salva: EIA_example1_pagina41_img1.png
# Imagem salva: EIA_example1_pagina41_img2.png
# Imagem salva: EIA_example1_pagina41_img3.png
# Imagem salva: EIA_example1_pagina41_img4.png
# Imagem salva: EIA_example1_pagina41_img5.jpeg
# Imagem salva: EIA_example1_pagina41_img6.png
# Imagem salva: EIA_example1_pagina41_img7.png
# Imagem salva: EIA_example1_pagina41_img8.jpeg
# Imagem salva: EIA_example1_pagina41_img9.jpeg
# Imagem salva: EIA_example1_pagina41_img10.jpeg
# Imagem salva: EIA_example1_pagina42_img1.png
# Imagem salva: EIA_example1_pagina42_img2.png
# Imagem salva: EIA_example1_pagina42_img3.png
# Imagem salva: EIA_example1_pagina42_img4.png
# Imagem salva: EIA_example1_pagina42_img5.jpeg
# Imagem salva: EIA_example1_pagina42_img6.png
# Imagem salva: EIA_example1_pagina42_img7.png
# Imagem salva: EIA_example1_pagina42_img8.jpeg
# Imagem salva: EIA_example1_pagina42_img9.jpeg
# Imagem salva: EIA_example1_pagina42_img10.jpeg
# Imagem salva: EIA_example1_pagina43_img1.png
# Imagem salva: EIA_example1_pagina43_img2.png
# Imagem salva: EIA_example1_pagina43_img3.png
# Imagem salva: EIA_example1_pagina43_img4.png
# Imagem salva: EIA_example1_pagina43_img5.jpeg
# Imagem salva: EIA_example1_pagina43_img6.png
# Imagem salva: EIA_example1_pagina43_img7.png
# Imagem salva: EIA_example1_pagina43_img8.jpeg
# Imagem salva: EIA_example1_pagina43_img9.jpeg
# Imagem salva: EIA_example1_pagina43_img10.jpeg
# Imagem salva: EIA_example1_pagina44_img1.png
# Imagem salva: EIA_example1_pagina44_img2.jpeg
# Imagem salva: EIA_example1_pagina44_img3.png
# Imagem salva: EIA_example1_pagina44_img4.png
# Imagem salva: EIA_example1_pagina44_img5.png
# Imagem salva: EIA_example1_pagina44_img6.png
# Imagem salva: EIA_example1_pagina44_img7.png
# Imagem salva: EIA_example1_pagina44_img8.jpeg
# Imagem salva: EIA_example1_pagina44_img9.png
# Imagem salva: EIA_example1_pagina44_img10.png
# Imagem salva: EIA_example1_pagina45_img1.png
# Imagem salva: EIA_example1_pagina45_img2.png
# Imagem salva: EIA_example1_pagina45_img3.jpeg
# Imagem salva: EIA_example1_pagina45_img4.png
# Imagem salva: EIA_example1_pagina45_img5.png
# Imagem salva: EIA_example1_pagina45_img6.png
# Imagem salva: EIA_example1_pagina45_img7.png
# Imagem salva: EIA_example1_pagina45_img8.jpeg
# Imagem salva: EIA_example1_pagina46_img1.png
# Imagem salva: EIA_example1_pagina46_img2.png
# Imagem salva: EIA_example1_pagina46_img3.jpeg
# Imagem salva: EIA_example1_pagina46_img4.png
# Imagem salva: EIA_example1_pagina46_img5.png
# Imagem salva: EIA_example1_pagina46_img6.jpeg
# Imagem salva: EIA_example1_pagina46_img7.png
# Imagem salva: EIA_example1_pagina46_img8.png
# Imagem salva: EIA_example1_pagina46_img9.png
# Imagem salva: EIA_example1_pagina46_img10.png
# Imagem salva: EIA_example1_pagina46_img11.jpeg
# Imagem salva: EIA_example1_pagina46_img12.png
# Imagem salva: EIA_example1_pagina46_img13.png
# Imagem salva: EIA_example1_pagina46_img14.jpeg
# Imagem salva: EIA_example1_pagina47_img1.png
# Imagem salva: EIA_example1_pagina47_img2.png
# Imagem salva: EIA_example1_pagina47_img3.png
# Imagem salva: EIA_example1_pagina47_img4.png
# Imagem salva: EIA_example1_pagina47_img5.png
# Imagem salva: EIA_example1_pagina48_img1.jpeg
# Imagem salva: EIA_example1_pagina49_img1.jpeg
# Imagem salva: EIA_example1_pagina50_img1.jpeg
# Imagem salva: EIA_example1_pagina51_img1.jpeg
# Imagem salva: EIA_example1_pagina52_img1.jpeg
# Imagem salva: EIA_example1_pagina53_img1.jpeg
# Imagem salva: EIA_example1_pagina54_img1.jpeg
# Imagem salva: EIA_example1_pagina55_img1.jpeg
# Imagem salva: EIA_example1_pagina56_img1.jpeg
# Imagem salva: EIA_example1_pagina57_img1.jpeg
# Imagem salva: EIA_example1_pagina58_img1.jpeg
# Imagem salva: EIA_example1_pagina59_img1.jpeg
# Imagem salva: EIA_example1_pagina60_img1.jpeg
# Imagem salva: EIA_example1_pagina60_img2.jpeg
# Imagem salva: EIA_example1_pagina60_img3.jpeg
# Imagem salva: EIA_example1_pagina61_img1.jpeg
# Imagem salva: EIA_example1_pagina61_img2.jpeg
# Imagem salva: EIA_example1_pagina62_img1.jpeg
# Imagem salva: EIA_example1_pagina62_img2.jpeg
# Imagem salva: EIA_example1_pagina63_img1.jpeg
# Imagem salva: EIA_example1_pagina63_img2.jpeg
# Imagem salva: EIA_example1_pagina64_img1.jpeg
# Imagem salva: EIA_example1_pagina64_img2.jpeg
# Imagem salva: EIA_example1_pagina65_img1.jpeg
# Imagem salva: EIA_example1_pagina66_img1.jpeg
# Imagem salva: EIA_example1_pagina67_img1.jpeg
# Imagem salva: EIA_example1_pagina68_img1.jpeg
# Imagem salva: EIA_example1_pagina69_img1.jpeg
# Imagem salva: EIA_example1_pagina70_img1.jpeg
# Imagem salva: EIA_example1_pagina71_img1.jpeg
# Imagem salva: EIA_example1_pagina72_img1.jpeg
# Imagem salva: EIA_example1_pagina73_img1.jpeg
# Imagem salva: EIA_example1_pagina74_img1.jpeg
# Imagem salva: EIA_example1_pagina75_img1.jpeg
# Imagem salva: EIA_example1_pagina76_img1.jpeg
# Imagem salva: EIA_example1_pagina77_img1.jpeg
# Imagem salva: EIA_example1_pagina78_img1.jpeg
# Imagem salva: EIA_example1_pagina79_img1.jpeg
# Imagem salva: EIA_example1_pagina80_img1.jpeg
# Imagem salva: EIA_example1_pagina81_img1.jpeg
# Imagem salva: EIA_example1_pagina82_img1.jpeg
# Imagem salva: EIA_example1_pagina83_img1.jpeg
# Imagem salva: EIA_example1_pagina84_img1.jpeg
# Imagem salva: EIA_example1_pagina85_img1.jpeg
# Imagem salva: EIA_example1_pagina86_img1.jpeg
# Imagem salva: EIA_example1_pagina87_img1.jpeg
# Imagem salva: EIA_example1_pagina88_img1.jpeg
# Imagem salva: EIA_example1_pagina89_img1.jpeg
# Imagem salva: EIA_example1_pagina90_img1.jpeg
# Imagem salva: EIA_example1_pagina91_img1.jpeg
# Imagem salva: EIA_example1_pagina92_img1.jpeg
# Imagem salva: EIA_example1_pagina93_img1.jpeg
# Imagem salva: EIA_example1_pagina94_img1.jpeg
# Imagem salva: EIA_example1_pagina95_img1.jpeg
# Imagem salva: EIA_example1_pagina96_img1.jpeg
# Imagem salva: EIA_example1_pagina96_img2.jpeg
# Imagem salva: EIA_example1_pagina97_img1.jpeg
# Imagem salva: EIA_example1_pagina98_img1.jpeg
# Imagem salva: EIA_example1_pagina98_img2.jpeg
# Imagem salva: EIA_example1_pagina99_img1.jpeg
# Imagem salva: EIA_example1_pagina99_img2.jpeg
# Imagem salva: EIA_example1_pagina99_img3.jpeg
# Imagem salva: EIA_example1_pagina100_img1.jpeg
# Imagem salva: EIA_example1_pagina100_img2.jpeg
# Imagem salva: EIA_example1_pagina101_img1.jpeg
# Imagem salva: EIA_example1_pagina102_img1.jpeg
# Imagem salva: EIA_example1_pagina103_img1.jpeg
# Imagem salva: EIA_example1_pagina103_img2.jpeg
# Imagem salva: EIA_example1_pagina104_img1.jpeg
# Imagem salva: EIA_example1_pagina104_img2.jpeg
# Imagem salva: EIA_example1_pagina104_img3.jpeg
# Imagem salva: EIA_example1_pagina105_img1.jpeg
# Imagem salva: EIA_example1_pagina105_img2.jpeg
# Imagem salva: EIA_example1_pagina105_img3.jpeg
# Imagem salva: EIA_example1_pagina105_img4.jpeg
# Imagem salva: EIA_example1_pagina106_img1.jpeg
# Imagem salva: EIA_example1_pagina106_img2.jpeg
# Imagem salva: EIA_example1_pagina106_img3.jpeg
# Imagem salva: EIA_example1_pagina107_img1.jpeg
# Imagem salva: EIA_example1_pagina108_img1.jpeg
# Imagem salva: EIA_example1_pagina108_img2.jpeg
# Imagem salva: EIA_example1_pagina109_img1.jpeg
# Imagem salva: EIA_example1_pagina109_img2.jpeg
# Imagem salva: EIA_example1_pagina110_img1.jpeg
# Imagem salva: EIA_example1_pagina110_img2.jpeg
# Imagem salva: EIA_example1_pagina111_img1.jpeg
# Imagem salva: EIA_example1_pagina112_img1.jpeg
# Imagem salva: EIA_example1_pagina113_img1.jpeg
# Imagem salva: EIA_example1_pagina114_img1.jpeg
# Imagem salva: EIA_example1_pagina115_img1.jpeg
# Imagem salva: EIA_example1_pagina116_img1.jpeg
# Imagem salva: EIA_example1_pagina116_img2.jpeg
# Imagem salva: EIA_example1_pagina117_img1.jpeg
# Imagem salva: EIA_example1_pagina117_img2.jpeg
# Imagem salva: EIA_example1_pagina118_img1.jpeg
# Imagem salva: EIA_example1_pagina119_img1.jpeg
# Imagem salva: EIA_example1_pagina119_img2.jpeg
# Imagem salva: EIA_example1_pagina119_img3.jpeg
# Imagem salva: EIA_example1_pagina120_img1.jpeg
# Imagem salva: EIA_example1_pagina120_img2.jpeg
# Imagem salva: EIA_example1_pagina121_img1.jpeg
# Imagem salva: EIA_example1_pagina121_img2.jpeg
# Imagem salva: EIA_example1_pagina122_img1.jpeg
# Imagem salva: EIA_example1_pagina122_img2.jpeg
# Imagem salva: EIA_example1_pagina122_img3.jpeg
# Imagem salva: EIA_example1_pagina122_img4.jpeg
# Imagem salva: EIA_example1_pagina123_img1.jpeg
# Imagem salva: EIA_example1_pagina124_img1.jpeg
# Imagem salva: EIA_example1_pagina125_img1.jpeg
# Imagem salva: EIA_example1_pagina125_img2.jpeg
# Imagem salva: EIA_example1_pagina126_img1.jpeg
# Imagem salva: EIA_example1_pagina126_img2.jpeg
# Imagem salva: EIA_example1_pagina126_img3.jpeg
# Imagem salva: EIA_example1_pagina127_img1.jpeg
# Imagem salva: EIA_example1_pagina128_img1.jpeg
# Imagem salva: EIA_example1_pagina129_img1.jpeg
# Imagem salva: EIA_example1_pagina130_img1.jpeg
# Imagem salva: EIA_example1_pagina130_img2.jpeg
# Imagem salva: EIA_example1_pagina131_img1.jpeg
# Imagem salva: EIA_example1_pagina132_img1.jpeg
# Imagem salva: EIA_example1_pagina133_img1.jpeg
# Imagem salva: EIA_example1_pagina134_img1.jpeg
# Imagem salva: EIA_example1_pagina134_img2.png
# Imagem salva: EIA_example1_pagina134_img3.jpeg
# Imagem salva: EIA_example1_pagina134_img4.jpeg
# Imagem salva: EIA_example1_pagina134_img5.jpeg
# Imagem salva: EIA_example1_pagina135_img1.jpeg
# Imagem salva: EIA_example1_pagina135_img2.jpeg
# Imagem salva: EIA_example1_pagina136_img1.jpeg
# Imagem salva: EIA_example1_pagina136_img2.jpeg
# Imagem salva: EIA_example1_pagina137_img1.jpeg
# Imagem salva: EIA_example1_pagina137_img2.jpeg
# Imagem salva: EIA_example1_pagina138_img1.jpeg
# Imagem salva: EIA_example1_pagina139_img1.jpeg
# Imagem salva: EIA_example1_pagina140_img1.jpeg
# Imagem salva: EIA_example1_pagina141_img1.jpeg
# Imagem salva: EIA_example1_pagina142_img1.jpeg
# Imagem salva: EIA_example1_pagina143_img1.jpeg
# Imagem salva: EIA_example1_pagina144_img1.jpeg
# Imagem salva: EIA_example1_pagina145_img1.jpeg
# Imagem salva: EIA_example1_pagina161_img1.jpeg
# Imagem salva: EIA_example1_pagina162_img1.jpeg
# Imagem salva: EIA_example1_pagina162_img2.jpeg
# Imagem salva: EIA_example1_pagina162_img3.jpeg
# Imagem salva: EIA_example1_pagina163_img1.jpeg
# Imagem salva: EIA_example1_pagina164_img1.png
# Imagem salva: EIA_example1_pagina164_img2.jpeg
# Imagem salva: EIA_example1_pagina166_img1.jpeg
# Imagem salva: EIA_example1_pagina166_img2.jpeg
# Imagem salva: EIA_example1_pagina166_img3.jpeg
# Imagem salva: EIA_example1_pagina167_img1.jpeg
# Imagem salva: EIA_example1_pagina167_img2.jpeg
# Imagem salva: EIA_example1_pagina167_img3.jpeg
# Imagem salva: EIA_example1_pagina168_img1.jpeg
# Imagem salva: EIA_example1_pagina168_img2.jpeg
# Imagem salva: EIA_example1_pagina168_img3.jpeg
# Imagem salva: EIA_example1_pagina169_img1.jpeg
# Imagem salva: EIA_example1_pagina169_img2.jpeg
# Imagem salva: EIA_example1_pagina169_img3.jpeg
# Imagem salva: EIA_example1_pagina170_img1.jpeg
# Imagem salva: EIA_example1_pagina170_img2.jpeg
# Imagem salva: EIA_example1_pagina170_img3.jpeg
# Imagem salva: EIA_example1_pagina171_img1.jpeg
# Imagem salva: EIA_example1_pagina171_img2.jpeg
# Imagem salva: EIA_example1_pagina171_img3.jpeg
# Imagem salva: EIA_example1_pagina172_img1.jpeg
# Imagem salva: EIA_example1_pagina172_img2.jpeg
# Imagem salva: EIA_example1_pagina172_img3.jpeg
# Imagem salva: EIA_example1_pagina173_img1.jpeg
# Imagem salva: EIA_example1_pagina173_img2.jpeg
# Imagem salva: EIA_example1_pagina173_img3.jpeg
# Imagem salva: EIA_example1_pagina174_img1.jpeg
# Imagem salva: EIA_example1_pagina174_img2.jpeg
# Imagem salva: EIA_example1_pagina174_img3.jpeg
# Imagem salva: EIA_example1_pagina175_img1.jpeg
# Imagem salva: EIA_example1_pagina175_img2.jpeg
# Imagem salva: EIA_example1_pagina175_img3.jpeg
# Imagem salva: EIA_example1_pagina176_img1.jpeg
# Imagem salva: EIA_example1_pagina176_img2.jpeg
# Imagem salva: EIA_example1_pagina176_img3.jpeg
# Imagem salva: EIA_example1_pagina177_img1.jpeg
# Imagem salva: EIA_example1_pagina177_img2.jpeg
# Imagem salva: EIA_example1_pagina177_img3.jpeg
# Imagem salva: EIA_example1_pagina178_img1.jpeg
# Imagem salva: EIA_example1_pagina178_img2.jpeg
# Imagem salva: EIA_example1_pagina178_img3.jpeg
# Imagem salva: EIA_example1_pagina179_img1.jpeg
# Imagem salva: EIA_example1_pagina179_img2.jpeg
# Imagem salva: EIA_example1_pagina179_img3.jpeg
# Imagem salva: EIA_example1_pagina189_img1.jpeg
# Imagem salva: EIA_example1_pagina189_img2.jpeg
# Imagem salva: EIA_example1_pagina203_img1.jpeg
# Imagem salva: EIA_example1_pagina203_img2.jpeg
# Imagem salva: EIA_example1_pagina203_img3.jpeg
# Imagem salva: EIA_example1_pagina203_img4.jpeg
# Imagem salva: EIA_example1_pagina203_img5.jpeg
# Imagem salva: EIA_example1_pagina204_img1.jpeg
# Imagem salva: EIA_example1_pagina204_img2.jpeg
# Imagem salva: EIA_example1_pagina204_img3.jpeg
# Imagem salva: EIA_example1_pagina204_img4.jpeg
#
# ✅ Extração de imagens concluída.

# %%
# Palavras-chave comuns em gráficos/mapas
KEYWORDS = ['gráfico', 'grafico', 'mapa', 'legenda', 'fonte', 'dados', 'eixo', 'percentual', 'escala', 'curva']

# Pastas
input_folder = Path("../extracted_images")
output_folder = Path("../filtered_images")
output_folder.mkdir(exist_ok=True)

# Função para verificar se imagem contém palavras-chave
def contains_keywords(image_path):
    try:
        text = pytesseract.image_to_string(Image.open(image_path), lang='por')
        return any(keyword in text.lower() for keyword in KEYWORDS)
    except Exception as e:
        print(f"[ERRO] {image_path.name}: {e}")
        return False

# Processamento
total = 0
movidas = 0

for image_path in input_folder.glob("*"):
    if image_path.is_dir():
        continue
    total += 1
    if contains_keywords(image_path):
        shutil.copy(image_path, output_folder / image_path.name)
        movidas += 1
        print(f"[OK] {image_path.name} => filtrada e copiada.")

print(f"\nTotal de imagens processadas: {total}")
print(f"Total de imagens copiadas: {movidas}")
# Out:
# [OK] EIA_example1_pagina35_img1.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina60_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina60_img3.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina61_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina63_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina96_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina98_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina100_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina108_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina119_img3.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina121_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina122_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina130_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina136_img2.jpeg => filtrada e copiada.
# [OK] EIA_example1_pagina137_img2.jpeg => filtrada e copiada.
# [OK] RIMA_example1_pagina4_img1.jpeg => filtrada e copiada.
# [OK] RIMA_example1_pagina8_img1.jpeg => filtrada e copiada.
# [OK] RIMA_example1_pagina18_img3.jpeg => filtrada e copiada.
# [OK] RIMA_example1_pagina19_img1.jpeg => filtrada e copiada.
#
# Total de imagens processadas: 431
# Total de imagens copiadas: 19

# %%
input_dir = Path("../filtered_images")
output_dir = Path("../described_images")
output_dir.mkdir(parents=True, exist_ok=True)

for image_path in input_dir.glob("*.[pjPJ]*[npNP]*[gG]*"):  # PNG ou JPG
    try:
        image = Image.open(image_path).convert("L")  # escala de cinza
        image = image.filter(ImageFilter.SHARPEN)
        image = ImageEnhance.Contrast(image).enhance(2)

        text = pytesseract.image_to_string(image, lang="por")

        # Salva o texto extraído
        output_txt_path = output_dir / (image_path.stem + ".txt")
        with open(output_txt_path, "w", encoding="utf-8") as f:
            f.write(text)

        print(f"[OK] {image_path.name}")

    except Exception as e:
        print(f"[ERRO] {image_path.name}: {e}")
# Out:
# [OK] EIA_example1_pagina35_img1.jpeg
# [OK] EIA_example1_pagina60_img2.jpeg
# [OK] EIA_example1_pagina60_img3.jpeg
# [OK] EIA_example1_pagina61_img2.jpeg
# [OK] EIA_example1_pagina63_img2.jpeg
# [OK] EIA_example1_pagina96_img2.jpeg
# [OK] EIA_example1_pagina98_img2.jpeg
# [OK] EIA_example1_pagina100_img2.jpeg
# [OK] EIA_example1_pagina108_img2.jpeg
# [OK] EIA_example1_pagina119_img3.jpeg
# [OK] EIA_example1_pagina121_img2.jpeg
# [OK] EIA_example1_pagina122_img2.jpeg
# [OK] EIA_example1_pagina136_img2.jpeg
# [OK] EIA_example1_pagina137_img2.jpeg
# [OK] RIMA_example1_pagina4_img1.jpeg
# [OK] RIMA_example1_pagina8_img1.jpeg
# [OK] RIMA_example1_pagina18_img3.jpeg
# [OK] RIMA_example1_pagina19_img1.jpeg
# [OK] EIA_example1_pagina130_img2.jpeg

# %%
known_places = [
    # Estados
    "Acre", "Alagoas", "Amapá", "Amazonas", "Bahia", "Ceará", "Distrito Federal", "Espírito Santo", "Goiás",
    "Maranhão", "Mato Grosso", "Mato Grosso do Sul", "Minas Gerais", "Pará", "Paraíba", "Paraná", "Pernambuco",
    "Piauí", "Rio de Janeiro", "Rio Grande do Norte", "Rio Grande do Sul", "Rondônia", "Roraima", "Santa Catarina",
    "São Paulo", "Sergipe", "Tocantins",

    # Principais cidades
    "São Paulo", "Rio de Janeiro", "Belo Horizonte", "Brasília", "Salvador", "Curitiba", "Fortaleza", "Manaus",
    "Recife", "Campinas", "Goiânia", "Belém", "Porto Alegre", "São Luís", "Natal", "Maceió", "João Pessoa",
    "Aracaju", "Cuiabá", "Campo Grande", "Florianópolis", "Vitória", "Macapá", "Rio Branco", "Palmas"
]

# %%
def extract_location_metadata(text: str) -> dict:
    metadata = {}

    # Coordenadas UTM simples
    utm_matches = re.findall(r"\b\d{6,7}\b", text)
    if utm_matches:
        metadata["utm_coords"] = ", ".join(set(utm_matches))

    places_found = [p for p in known_places if p.lower() in text.lower()]
    if places_found:
        metadata["places"] = ", ".join(sorted(set(places_found)))

    return metadata

# %%
# Inicializa o modelo de embeddings local
model = SentenceTransformer("all-MiniLM-L6-v2")

# Caminho para as descrições
desc_dir = Path("../described_images")
desc_files = list(desc_dir.glob("*.txt"))

# Chroma DB
chroma_client = chromadb.PersistentClient(path="./chroma_db")
collection = chroma_client.get_or_create_collection("image_descriptions")

# MongoDB
mongo_client = MongoClient("mongodb://localhost:27017/")
mongo_db = mongo_client["rag_db"]
image_chunks = mongo_db["image_chunks"]

# Processamento
for txt_file in desc_files:
    with open(txt_file, "r", encoding="utf-8") as f:
        description = f.read().strip()

    if not description:
        continue

    embedding = model.encode(description).tolist()
    doc_id = str(uuid.uuid4())

    location_metadata = extract_location_metadata(description)
    # Armazena no Chroma
    collection.add(
        documents=[description],
        embeddings=[embedding],
        ids=[doc_id],
        metadatas=[{
            "source": txt_file.name,
            **location_metadata
        }]
    )
    # Armazena no MongoDB
    image_chunks.insert_one({
        "id": doc_id,
        "source": txt_file.name,
        "text": description,
        "embedding": embedding
    })


    print(f"[OK] {txt_file.name} armazenado")
# Out:
# [OK] EIA_example1_pagina35_img1.txt armazenado
# [OK] EIA_example1_pagina60_img2.txt armazenado
# [OK] EIA_example1_pagina60_img3.txt armazenado
# [OK] EIA_example1_pagina61_img2.txt armazenado
# [OK] EIA_example1_pagina63_img2.txt armazenado
# [OK] EIA_example1_pagina96_img2.txt armazenado
# [OK] EIA_example1_pagina98_img2.txt armazenado
# [OK] EIA_example1_pagina100_img2.txt armazenado
# [OK] EIA_example1_pagina108_img2.txt armazenado
# [OK] EIA_example1_pagina119_img3.txt armazenado
# [OK] EIA_example1_pagina121_img2.txt armazenado
# [OK] EIA_example1_pagina122_img2.txt armazenado
# [OK] EIA_example1_pagina136_img2.txt armazenado
# [OK] EIA_example1_pagina137_img2.txt armazenado
# [OK] RIMA_example1_pagina4_img1.txt armazenado
# [OK] RIMA_example1_pagina8_img1.txt armazenado
# [OK] RIMA_example1_pagina18_img3.txt armazenado
# [OK] RIMA_example1_pagina19_img1.txt armazenado
# [OK] EIA_example1_pagina130_img2.txt armazenado

# %%
chroma_client = chromadb.PersistentClient(path="./chroma_db")

# %%
collections = chroma_client.list_collections()

# Exibe os nomes das collections
for c in collections:
    print(c.name)
# Out:
# rag_embeddings
# image_contexts
# image_descriptions
